# %%
import torch
from torch.utils.data import Dataset
from datasets import load_dataset
from transformers import AutoTokenizer
import pandas as pd
import polars as pl

# %%
path = "../../JoeyData/10BT/000_00000.parquet"
tokenizer = AutoTokenizer.from_pretrained("SouthernCrossAI/JoeyLLM_Tokenizer", use_fast=True)

# %%
df = pd.read_parquet(path, columns=["text"])

# %%
from datasets import Dataset
dataset = Dataset.from_pandas(df)

# %%
tokenized_dataset = dataset.map(tokenizer, batched=True, num_proc=45)
# Out:
# Map (num_proc=45):   0%|          | 0/1048581 [00:00<?, ? examples/s]
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-41:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-45:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-40:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-27:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-13:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-25:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-4:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-2:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-1:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 385, in get
#     res = self._reader.recv_bytes()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/connection.py", line 440, in _recv_bytes
#     return self._recv(size)
#            ^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/connection.py", line 398, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-22:
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
# Process ForkPoolWorker-23:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#   File "/home/remote/u1138167/JoeyLLM/.venv/lib/python3.12/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
full_text = " ".join(df["text"].dropna())

# %%
type(full_text)
# Out:
# str

# %%
full_text[:10]
# Out:
# '|Viewing S'

# %%
total_char_count = df["text"].str.len().sum()

# %%
total_char_count
# Out:
# np.int64(3204508391)

# %%
df.shape
# Out:
# (1048581, 1)

# %%
tokens = tokenizer(full_text)
